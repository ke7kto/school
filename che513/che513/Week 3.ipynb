# %% [markdown]
# $H\Psi = \lambda\Psi$<br>
# momentum = $p$<br>
# position = $q$<br><br>
# For single particles, we can express $H$ as a function
#
# $H(p,q) = K(p) + U(q) = \frac{p^2}{2m} + U(q)$
#
# $\left(\frac{\partial H}{\partial p_j}\right)_{k\neq j, q_k} = \dot{q}_j$
#
# $\left(\frac{\partial H}{\partial q_j}\right)_{k\neq j, p_k} = \dot{p}_j$
# <br>
# Hamiltonian represents the energy of the system
# <br>
# $\Psi = A \exp{\left[2\pi i \left(\frac{q}{\lambda} - vt\right)\right]}$
# <br>
# You could do this with trigonometric functions, but it's easier to do with imaginary numbers.
# <h3>Operators</h3>
# <h5>Momentum</h5>
# $p \Rightarrow \hat{p} = \frac{h}{2\pi i}\nabla$
#
# $E \Rightarrow \hat{E} = -\frac{h}{2\pi i}\frac{\partial}{\partial t}$
#
# $\langle$Expectation Value$\rangle$
#
# To calculate the expectation value, integrate the property you wish to get the expectation value of multiplied by it's probability. Normalize this by dividing by the integral of the probabilities
# <br><br>
# $\langle E\rangle = \frac{\int\Psi^\ast \hat{H}\Psi dq}{\int \Psi^\ast\Psi dq}$
# <br><br/>
# Electronic wave function<br><br/>
#
# $\hat{H}=-\frac{h^2}{8\pi^2}\Sigma_i\frac{1}{m_i}\left(\frac{\partial^2}{\partial x_i^2}+\frac{\partial^2}{\partial y_i^2}+\frac{\partial^2}{\partial z_i^2}\right)$
# $-\frac{1}{4\pi\epsilon_0}\left(\sum_{i}^{electrons}\sum_s^{nuclei}\frac{Z_s e}{r_{is}} - \sum_{i<j}^{electrons}\sum\frac{e^2}{r_{ij}} - \sum_{s<t}^{nuclei}\sum\frac{Z_s Z_t}{r_{st}}\right)$
#
# <h3>Units</h3>
# We use Hartree for our energy units, Bohrs for length, amu for mass, and e for charge
#
# <h3>Hydrogen atom</h3>
#
# $\hat{H} = -\frac{1}{2}\nabla^2 - \frac{1}{r}$
# <h5>interesting function of note</h5>
# Laguerre polynomial of order n<br>
# Legendre polynomial
# <br>
# <br>
# L,n,m quantum numbers
# $n$ tells me what row of the periodic table<br>
# $L$ tells me what orbital ($s,p,d,f$), etc.<br>
# $m$ tells me what orientation ($-1=x,\:0=y,\:1=z$)<br>
# <br>
# $\phi_{nlm} = R_{nl}(r)\dot Y_{lm}(\theta,\varphi)$
#
# $R_{nl}(r)=2\left[\left(\frac{\zeta}{a_0}\right)^3\frac{(n-l-1)!}{n\left[(n+1)!\right]^3}\right]^\frac{1}{2} \left(2r\zeta\right)^l e^{-r\zeta} \frac{d^{2l+1}L_{n+1}(\rho)}{d \rho^{2l+1}}$<br>
# $\zeta \equiv \frac{Z}{n}$<br>
# $\rho \equiv 2\zeta r$
# <h4>Yikes, let's simplify!</h4>
# $R_{n}(r)=\frac{(2\zeta)^{n+1/2}}{\sqrt{2n!}}r^{n-1} e^{-r\zeta}$
# <p>
# The variational principle is that we attempt to find the wave function based on minimizing the energy. "The lowest energy we can get must be the wave function"</p>
# <p>
# We can do a linear combination of orbitals to add more variability to the shape of the orbital</p>
#
# $\psi_j = \sum_{i=1}^k c_{i,j}\phi_i$
# <p>But as we increase $\phi$'s complexity, although we increase $\Psi$'s possible range of values, we increase computation time ($\frac{B^4}{8}$ where $B$ is the number of basis functions)</p>
#
# <p>Born-Oppenheimer approximation is good for finding geometries and relative energies</p>
#
# <h4>Slater determinants are hard, let's use something else</h4>
#
# <p>Gaussian orbitals are good approximations to slater orbitals, but we need to use multiple gaussians (Gaussian:slater::3:1)</p>
#
# $\phi_j = \sum_{i=1}^L d_{ij}g_{i}$<br><br>
#
# $g = Cx^a y^b z^c \exp(-\alpha r^2)$

# %% [markdown]
# <h4>Fourier Series</h4>
# <p>
# $S(x) = a_0 + \sum_{k=1}^K a_k cos(\frac{2\pi kt}{T}) + \sum_{k=1}^K b_k sin(\frac{2\pi k t}{T})$
#
# </p>

# %% [markdown]
# <h4>
# STO-3G Basis Set
# </h4>
# <p>STO-3G is the minimum basis set. Here are some examples</p>
# <p>Hydrogen: $1s$</p>
# <p>Carbon: $1s,2s,2p_x,2p_y,2p_z$</p>
# <p>Neon: $1s,2s,2p_x,2p_y,2p_z$</p>
#
# <h4>
# 3-21G Basis Set
# </h4>
# <p></p>
# <p>Hydrogen: $1s(2g),1s^\prime (1g)$, B=2; G=3</p>
# <p>Carbon: $1s(3g),2s(2g),2s^\prime(1g),2p_x(2g),2p_x^\prime (g),2p_y(2g),2p_y^\prime (1g),2p_z (2g),2p_z^\prime (1g)$ B=9; G=15</p>
# <p>Neon: $1s,2s,2p_x,2p_y,2p_z$</p>
#
# <h4>6-31G</h4>
# <p>6: How many gaussians for core electrons, 3 for the number of gaussians </p>
#
# <p>6-31G(d) or 6-31G*->Only heavy atoms are polarized. 6-31G** or 6-31G(d,p) for all atoms</p>
