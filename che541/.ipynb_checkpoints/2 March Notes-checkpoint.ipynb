# %% [markdown]
# <h1>Parabolic PDE's</h1>
# PDE types:
#
# 1. Parabolic
# 2. Hyperbolic
# 3. Elliptic
#
# <p>

# %%
x = np.linspace(0,1)
y = np.cosh(x)-np.sinh(x)
y2= np.cosh(x)+np.sinh(x)
plt.plot(x,y)
plt.plot(x,y2)
